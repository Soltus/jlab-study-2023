# %% [markdown]
# <h1 id="包含jupyter的依赖管理">原生依赖管理</h1>

# %%
# !pip freeze > requirements.txt
# Out:
# WARNING: Ignoring invalid distribution -upyter-core (d:\x-s01\conda3\envs\vsc\lib\site-packages)

# %%
# !pip install -r requirements.txt -i https://mirrors.tencent.com/pypi/simple

# %% [markdown]
# <h1>适用于Binder的依赖管理</h1>

# %%
# !pip install pip-tools

# %%
# requirements.in 使用了GBK编码，因此需要使用VSCode打开
# !python -m piptools compile --upgrade --resolver=backtracking requirements.in
# Out:
# WARNING:pip._internal.metadata.base:Ignoring invalid distribution -upyter-core (d:\x-s01\conda3\envs\vsc\lib\site-packages)
# #
# # This file is autogenerated by pip-compile with Python 3.9
# # by the following command:
# #
# #    pip-compile --resolver=backtracking requirements.in
# #
# --index-url https://mirrors.tencent.com/pypi/simple
#
# aiobotocore==2.4.2
#     # via s3fs
# aiofiles==22.1.0
#     # via ypy-websocket
# aiohttp==3.8.4
#     # via
#     #   -r requirements.in
#     #   aiobotocore
#     #   s3fs
# aioitertools==0.11.0
#     # via aiobotocore
# aiosignal==1.3.1
#     # via aiohttp
# aiosqlite==0.18.0
#     # via ypy-websocket
# altair==4.2.2
#     # via digautoprofiler
# anyio==3.6.2
#     # via
#     #   jupyter-server
#     #   starlette
# appdirs==1.4.4
#     # via pandasgui
# argon2-cffi==21.3.0
#     # via
#     #   jupyter-server
#     #   nbclassic
#     #   notebook
# argon2-cffi-bindings==21.2.0
#     # via argon2-cffi
# arrow==1.2.3
# ...

# %% [markdown]
# <h1>初始化工作</h1>

# %%
# REF https://nbdime.readthedocs.io/en/latest/
# !nbdime config-git --enable --global
